# %% [markdown]
# ### SPAM Ham Detection

# %%
import random
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
## Reading the given dataset
spam = pd.read_csv("SMSSpamCollection.txt", sep = "\t", names=["label", "message"])

# %%
print(spam.head())
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
## Converting the read dataset in to a list of tuples, each tuple(row) contianing the message and it's label
data_set = []
for index,row in spam.iterrows():
    data_set.append((row['message'], row['label']))

# %%
print(data_set[:5])
# Out:
# [('Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...', 'ham'), ('Ok lar... Joking wif u oni...', 'ham'), ("Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's", 'spam'), ('U dun say so early hor... U c already then say...', 'ham'), ("Nah I don't think he goes to usf, he lives around here though", 'ham')]

# %%
print(len(data_set))
# Out:
# 5572

# %% [markdown]
# ### Preprocessing

# %%
## initialise the inbuilt Stemmer and the Lemmatizer
stemmer = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()

# %%
def preprocess(document, stem=True):
    'changes document to lower case, removes stopwords and lemmatizes/stems the remainder of the sentence'

    # change sentence to lower case
    document = document.lower()

    # tokenize into words
    words = word_tokenize(document)

    # remove stop words
    words = [word for word in words if word not in stopwords.words("english")]

    if stem:
        words = [stemmer.stem(word) for word in words]
    else:
        words = [wordnet_lemmatizer.lemmatize(word, pos='v') for word in words]

    # join words to make sentence
    document = " ".join(words)

    return document

# %%
## - Performing the preprocessing steps on all messages
messages_set = []
for (message, label) in data_set:
    words_filtered = [e.lower() for e in preprocess(message, stem=False).split() if len(e) >= 3]
    messages_set.append((words_filtered, label))

# %%
print(messages_set[:5])
# Out:
# [(['jurong', 'point', 'crazy..', 'available', 'bugis', 'great', 'world', 'buffet', '...', 'cine', 'get', 'amore', 'wat', '...'], 'ham'), (['lar', '...', 'joke', 'wif', 'oni', '...'], 'ham'), (['free', 'entry', 'wkly', 'comp', 'win', 'cup', 'final', 'tkts', '21st', 'may', '2005.', 'text', '87121', 'receive', 'entry', 'question', 'std', 'txt', 'rate', 'apply', '08452810075over18'], 'spam'), (['dun', 'say', 'early', 'hor', '...', 'already', 'say', '...'], 'ham'), (['nah', "n't", 'think', 'usf', 'live', 'around', 'though'], 'ham')]

# %% [markdown]
# ### Preparing to create features

# %%
## - creating a single list of all words in the entire dataset for feature list creation

def get_words_in_messages(messages):
    all_words = []
    for (message, label) in messages:
      all_words.extend(message)
    return all_words

# %%
## - creating a final feature list using an intuitive FreqDist, to eliminate all the duplicate words
## Note : we can use the Frequency Distribution of the entire dataset to calculate Tf-Idf scores like we did earlier.

def get_word_features(wordlist):

    #print(wordlist[:10])
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

# %%
## - creating the word features for the entire dataset
word_features = get_word_features(get_words_in_messages(messages_set))
print(len(word_features))
# Out:
# 8395

# %% [markdown]
# ### Preparing to create a train and test set

# %%
## - creating slicing index at 80% threshold
sliceIndex = int((len(messages_set)*.8))

# %%
## - shuffle the pack to create a random and unbiased split of the dataset
random.shuffle(messages_set)

# %%
train_messages, test_messages = messages_set[:sliceIndex], messages_set[sliceIndex:]

# %%
len(train_messages)
len(test_messages)
# Out:
# 1115

# %% [markdown]
# ### Preparing to create feature maps for train and test data

# %%
## creating a LazyMap of feature presence for each of the 8K+ features with respect to each of the SMS messages
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
## - creating the feature map of train and test data

training_set = nltk.classify.apply_features(extract_features, train_messages)
testing_set = nltk.classify.apply_features(extract_features, test_messages)

# %%
print(training_set[:5])
# Out:
# [({'contains(smith)': False, 'contains(level)': False, 'contains(yoville)': False, 'contains(somtimes)': False, 'contains(hotels)': False, 'contains(tonite.busy)': False, 'contains(facts)': False, 'contains(christmas)': False, 'contains(buck)': False, 'contains(problem..)': False, 'contains(2gthr)': False, 'contains(administrator..)': False, 'contains(bsn)': False, 'contains(skillgame)': False, 'contains(vinobanagar)': False, 'contains(doors)': False, 'contains(deep)': False, 'contains(entry)': False, 'contains(12,000pes)': False, 'contains(favorite)': False, 'contains(name)': False, 'contains(dough)': False, 'contains(slightly)': False, 'contains(iter)': False, 'contains(system)': False, 'contains(idiot)': False, 'contains(cricketer)': False, 'contains(frank)': False, 'contains(oblivious)': False, 'contains(4.47per)': False, 'contains(tcr/w1)': False, 'contains(vilikkam)': False, 'contains(cartoon)': False, 'contains(09058091870)': False, 'contains(baby)': False, 'contains(applebees)': False, 'contains(biggest)': False, 'contains(ammo)': False, 'contains(tallent)': False, 'contains(nearby)': False, 'contains(resize)': False, 'contains(birthday)': False, 'contains(da..please)': False, 'contains(freeze)': False, 'contains(da..)': False, 'contains(bt-national)': False, 'contains(maga)': False, 'contains(receive..)': False, 'contains(jerry)': False, 'contains(tke)': False, 'contains(5.00)': False, 'contains(mush)': False, 'contains(08719181513)': False, 'contains(msn)': False, 'contains(+449071512431)': False, 'contains(blah)': False, 'contains(08715203677)': False, 'contains(kaaj)': False, 'contains(wallpaper)': False, 'contains(keris)': False, 'contains(gent)': False, 'contains(430)': False, 'contains(frankie)': False, 'contains(top)': False, 'contains(£250k)': False, 'contains(owe)': False, 'contains(alcohol)': False, 'contains(macho)': False, 'contains(fine.inshah)': False, 'contains(09061702893)': False, 'contains(lonely)': False, 'contains(analysis)': False, 'contains(21/11/04)': False, 'contains(reslove)': False, 'contains(smart..though)': False, 'contains(no-434)': False, 'contains(warm)': False, 'contains(claimcode)': False, 'contains(age16)': False, 'contains(versus)': False, 'contains(shelf)': False, 'contains(today.do)': False, 'contains(unbelievable)': False, 'contains(grams)': False, 'contains(certificate)': False, 'contains(time-hope)': False, 'contains(deepest)': False, 'contains(lotz)': False, 'contains(coz..somtimes)': False, 'contains(.by)': False, 'contains(return)': False, 'contains(kvb)': False, 'contains(wire3.net)': False, 'contains(08709501522)': False, 'contains(pick)': False, 'contains(question..)': False, 'contains(brainless)': False, 'contains(rhythm)': False, 'contains(hubby)': False, 'contains(luv)': False, 'contains(41782)': False, 'contains(vava)': False, 'contains(comfort)': False, 'contains(biola)': False, 'contains(venugopal)': False, 'contains(margaret)': False, 'contains(yeesh)': False, 'contains(jamster.co.uk)': False, 'contains(nimbomsons)': False, 'contains(rate)': False, 'contains(sed)': False, 'contains(fromm)': False, 'contains(gotany)': False, 'contains(do..)': False, 'contains(press)': False, 'contains(abstract)': False, 'contains(cloud)': False, 'contains(pimples..even)': False, 'contains(warn)': False, 'contains(smash)': False, 'contains(cloth)': False, 'contains(distract)': False, 'contains(it+both)': False, 'contains(steer)': False, 'contains(09066364349)': False, 'contains(sef)': False, 'contains(sterm)': False, 'contains(//www.wtlp.co.uk/text)': False, 'contains(freak)': False, 'contains(befor)': False, 'contains(08081263000)': False, 'contains(prescribe)': False, 'contains(2waxsto)': False, 'contains(hellogorgeous)': False, 'contains(chip)': False, 'contains(creep)': False, 'contains(prayrs..)': False, 'contains(messenger)': False, 'contains(no1)': False, 'contains(stress)': False, 'contains(us.get)': False, 'contains(publish)': False, 'contains(6.cruel)': False, 'contains(you\ ...

# %%
print('Training set size : ', len(training_set))
print('Test set size : ', len(testing_set))
# Out:
# Training set size :  4457
# Test set size :  1115

# %% [markdown]
# ### Training

# %%
## Training the classifier with NaiveBayes algorithm
spamClassifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [markdown]
# ### Evaluation

# %%
## - Analyzing the accuracy of the test set
print(nltk.classify.accuracy(spamClassifier, training_set))
# Out:
# 0.9923715503702042

# %%
## Analyzing the accuracy of the test set
print(nltk.classify.accuracy(spamClassifier, testing_set))
# Out:
# 0.9820627802690582

# %%
## Testing a example message with our newly trained classifier
m = 'CONGRATULATIONS!! As a valued account holder you have been selected to receive a £900 prize reward! Valid 12 hours only.'
print('Classification result : ', spamClassifier.classify(extract_features(m.split())))
# Out:
# Classification result :  spam

# %%
## Priting the most informative features in the classifier
print(spamClassifier.show_most_informative_features(50))
# Out:
# Most Informative Features
#          contains(award) = True             spam : ham    =    208.8 : 1.0
#         contains(urgent) = True             spam : ham    =    120.1 : 1.0
#           contains(code) = True             spam : ham    =     96.8 : 1.0
#          contains(await) = True             spam : ham    =     92.5 : 1.0
#          contains(video) = True             spam : ham    =     92.5 : 1.0
#          contains(nokia) = True             spam : ham    =     80.2 : 1.0
#           contains(rate) = True             spam : ham    =     71.0 : 1.0
#            contains(txt) = True             spam : ham    =     67.7 : 1.0
#       contains(delivery) = True             spam : ham    =     66.7 : 1.0
#       contains(landline) = True             spam : ham    =     65.9 : 1.0
#            contains(100) = True             spam : ham    =     62.4 : 1.0
#        contains(service) = True             spam : ham    =     61.6 : 1.0
#         contains(camera) = True             spam : ham    =     58.1 : 1.0
#      contains(statement) = True             spam : ham    =     58.1 : 1.0
#           contains(land) = True             spam : ham    =     53.8 : 1.0
#           contains(club) = True             spam : ham    =     49.5 : 1.0
#           contains(draw) = True             spam : ham    =     48.1 : 1.0
#         contains(latest) = True             spam : ham    =     47.0 : 1.0
#       contains(customer) = True             spam : ham    =     44.2 : 1.0
#         contains(orange) = True             spam : ham    =     43.4 : 1.0
#         contains(mobile) = True             spam : ham    =     42.3 : 1.0
#         contains(txting) = True             spam : ham    =     40.9 : 1.0
#       contains(discount) = True             spam : ham    =     40.9 : 1.0
#           contains(comp) = True             spam : ham    =     40.9 : 1.0
#           contains(quiz) = True             spam : ham    =     40.9 : 1.0
#        contains(attempt) = True             spam : ham    =     40.0 : 1.0
#        contains(network) = True             spam : ham    =     39.7 : 1.0
#          contains(apply) = True             spam : ham    =     38.0 : 1.0
#          contains(pound) = True             spam : ham    =     37.8 : 1.0
#           contains(cash) = True             spam : ham    =     37.6 : 1.0
#         contains(caller) = True             spam : ham    =     36.6 : 1.0
#            contains(box) = True             spam : ham    =     33.7 : 1.0
#            contains(mat) = True             spam : ham    =     32.3 : 1.0
#          contains(final) = True             spam : ham    =     32.3 : 1.0
#          contains(music) = True             spam : ham    =     32.3 : 1.0
#            contains(del) = True             spam : ham    =     32.3 : 1.0
#         contains(player) = True             spam : ham    =     29.7 : 1.0
#           contains(line) = True             spam : ham    =     29.3 : 1.0
#         contains(reward) = True             spam : ham    =     28.0 : 1.0
#      contains(fantastic) = True             spam : ham    =     28.0 : 1.0
#            contains(dvd) = True             spam : ham    =     28.0 : 1.0
#         contains(reveal) = True             spam : ham    =     28.0 : 1.0
#           contains(sony) = True             spam : ham    =     28.0 : 1.0
#           contains(user) = True             spam : ham    =     28.0 : 1.0
#         contains(summer) = True             spam : ham    =     28.0 : 1.0
#           contains(info) = True             spam : ham    =     27.1 : 1.0
#         contains(select) = True             spam : ham    =     25.2 : 1.0
#        contains(anytime) = True             spam : ham    =     24.5 : 1.0
#       contains(motorola) = True             spam : ham    =     24.5 : 1.0
#         contains(direct) = True             spam : ham    =     24.5 : 1.0
# None

# %%
## storing the classifier on disk for later usage
import pickle
f = open('nb_spam_classifier.pickle', 'wb')
pickle.dump(spamClassifier,f)
print('Classifier stored at ', f.name)
f.close()
# Out:
# Classifier stored at  nb_spam_classifier.pickle
